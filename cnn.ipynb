# %%
from roboflow import Roboflow
rf = Roboflow(api_key="ZXRq0IkAKXB0Ku5x411M")
project = rf.workspace().project("bubble-blkmf")
small_dataset = project.version(1).download('yolov8')
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.123, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to bubble-1 in yolov8:: 100%|██████████| 180/180 [00:00<00:00, 2326.13it/s]

# %%
# !cat {small_dataset.location}/data.yaml
{small_dataset.location}
# Out:
# names:
# - bubble
# nc: 1
# roboflow:
#   license: CC BY 4.0
#   project: bubble-blkmf
#   url: https://universe.roboflow.com/trajectoryprediction-zlakf/bubble-blkmf/dataset/1
#   version: 1
#   workspace: trajectoryprediction-zlakf
# test: test/images
# train: train/images
# val: valid/images
# {'/Users/austin/Desktop/bubble-detection/bubble-1'}

# %% [markdown]
# Train model on small dataset

# %%
# !yolo task=detect mode=train model=yolov8s.pt data={small_dataset.location}/data.yaml epochs=100 imgsz=640 device=mps
# Out:
# ...
# 100%|██████████████████████████████████████| 21.5M/21.5M [00:01<00:00, 21.6MB/s]
# Ultralytics YOLOv8.0.123 🚀 Python-3.11.0 torch-2.0.1 MPS
# ...

# %%
# !yolo task=detect mode=predict model=yolov5/runs/detect/train/weights/best.pt conf=0.25 source=/Users/austin/Desktop/bubble-detection/images
# Out:
# Ultralytics YOLOv8.0.123 🚀 Python-3.11.0 torch-2.0.1 CPU
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/379 /Users/austin/Desktop/bubble-detection/images/input.mp4-0-00-00.00.jpg: 384x640 (no detections), 88.5ms
# image 2/379 /Users/austin/Desktop/bubble-detection/images/input.mp4-0-00-00.10.jpg: 384x640 (no detections), 78.1ms
# image 3/379 /Users/austin/Desktop/bubble-detection/images/input.mp4-0-00-00.20.jpg: 384x640 (no detections), 80.4ms
# image 4/379 /Users/austin/Desktop/bubble-detection/images/input.mp4-0-00-00.40.jpg: 384x640 (no detections), 80.4ms
# image 5/379 /Users/austin/Desktop/bubble-detection/images/input.mp4-0-00-00.50.jpg: 384x640 (no detections), 77.4ms
# image 6/379 /Users/austin/Desktop/bubble-detection/images/input.mp4-0-00-00.60.jpg: 384x640 (no detections), 71.9ms
# image 7/379 /Users/austin/Desktop/bubble-detection/images/input.mp4-0-00-00.70.jpg: 384x640 (no detections), 76.7ms
# ...
